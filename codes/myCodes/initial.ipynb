# %%
import os
from pathlib import Path
import pandas as pd

DATA_ROOT = Path(os.environ.get("OSV5M_DATA_DIR", Path.cwd() / "data" / "osv5m"))
df = pd.read_csv(DATA_ROOT / "test.csv", nrows=5)
print(df.columns.tolist())
print(df.head())
# Out:
# ['id', 'latitude', 'longitude', 'thumb_original_url', 'country', 'sequence', 'captured_at', 'lon_bin', 'lat_bin', 'cell', 'land_cover', 'road_index', 'drive_side', 'climate', 'soil', 'dist_sea', 'region', 'sub-region', 'city', 'unique_city', 'unique_sub-region', 'unique_region', 'unique_country', 'quadtree_10_1000', 'creator_username', 'creator_id']
#                  id   latitude  longitude  \
# 0   547473234108938 -16.336027  45.628280
# 1   826109781317024  50.855687  56.147997
# 2  1006398440000844  37.956651  14.954485
# 3  2943891539215481  12.373333  -8.909906
# 4   122945119799579   7.510295  99.061884
#
#                                   thumb_original_url country  \
# 0  https://scontent-cdg4-3.xx.fbcdn.net/m1/v/t6/A...      MG
# 1  https://scontent-cdg4-1.xx.fbcdn.net/m1/v/t6/A...      KZ
# 2  https://scontent-cdg4-1.xx.fbcdn.net/m1/v/t6/A...      IT
# 3  https://scontent-cdg4-1.xx.fbcdn.net/m1/v/t6/A...      ML
# ...
